# %%
import numpy as np
import sys
import time

# yeti modules
from preprocessing.igaparametrization import IGAparametrization, IGAmanip as manip
import postprocessing.postproc as pp
import reconstructionSOL as rsol

from preprocessing.igaparametrization import OPTmodelling

# %%
modeleIGA = IGAparametrization(filename='centrif_U1_C0')
# Out:
# Reading Abaqus inp file from centrif_U1_C0.inp...
#
# Reading number of nodes by element...
#
# Reading parameters defining the user elements...
#
# Reading model name...
# No model name.
#
# Reading parameters...
#
# Reading distributions...
# 0 distributions read.
#
# Reading materials...
# 	Reading material Mat...
# 		Type isotropic.
# 		Elastic modulus = 210000.0
# 		Poisson = 0.3
# 	Material Mat successfully read.
# 1 materials read.
#
# Reading parts...
# 	Reading part Piece...
# 		8 nodes read.
# 		1 elements read.
# 		2 groups read.
# 		1 properties read.
# 	Part Piece successfully read.
# 1 parts read.
#
# Saving part objects...
# Parts successfully saved.
#
# Reading assembly...
# Creating instance I1 of part Piece...
# Successfully created.
# 0 nodes read.
# 1 instances created.
#
# Reading initial boundary conditions...
# 	Initial step created.
# Initial boundary conditions read.
#
# Reading steps...
# 	Reading step ... No name
# 		Reading boundary condition...
# 		 - Boundary condition (bc with no name1) successfully added.
# 		Reading Dload ...
# 		 - Distributed load (no name) successfully added.
# 	Step No name successfully read with 1 bcs and 1 loads.
# 2 steps read.
#
# Abaqus inp file centrif_U1_C0.inp successfully read.

# %%
# Refinement to create optimisation model
nb_deg = np.zeros((3, modeleIGA._nb_patch),dtype=np.intp)
nb_ref = np.zeros((3, modeleIGA._nb_patch),dtype=np.intp)

nb_ref[:, 0] = np.array([0, 2, 0])
nb_deg[:, 0] = np.array([0, 1, 0])
additional_knots = {"patches": np.array([0]),
                    "1": np.array([]), "2": np.array([0.2,0.2]), "3": np.array([])}

#additional_knots = {"patches": np.array([0]),
#                    "1": np.array([]), "2": np.array([]), "3": np.array([])}


# Initial refinement (none)
modeleIGA.refine(nb_ref, nb_deg, additional_knots)
# Out:
#  Refinement has been successfully done.

# %%
modeleIGA._COORDS.shape
modeleIGA._Ukv
# Out:
# [[array([0., 0., 1., 1.]),
#   array([0.  , 0.  , 0.  , 0.05, 0.1 , 0.15, 0.2 , 0.2 , 0.4 , 0.6 , 0.8 ,
#          1.  , 1.  , 1.  ]),
#   array([0., 0., 1., 1.])]]

# %%
icp = np.where(modeleIGA._COORDS[1, :] > 1.2)[0]
nb_var = np.unique(modeleIGA._COORDS[1, icp]).size

# %%
# Define shape change from design variables
# min and max dimensions, assuming that design variables are in [0,1]
mindim = 0.1
maxdim = 3.5

def shapemodif(coords0, igapara, var):
    igapara._COORDS[:,:] = coords0[:,:]
    # shape change is made on points with y coord higher than 3
    icp = np.where(modeleIGA._COORDS[1, :] > 1.2)[0]
    i = 0
    for y in np.unique(modeleIGA._COORDS[1, icp]):
        # WARNING exact real value comparison is unsafe
        jcp = np.where(modeleIGA._COORDS[1, :] == y)[0]
    
        #igapara._COORDS[0, jcp[0]] = - (mindim + var[i]*(maxdim-mindim))/2.
        igapara._COORDS[2, jcp[0]] = - (mindim + var[i]*(maxdim-mindim))/2.
        
        #igapara._COORDS[0, jcp[1]] =   (mindim + var[i]*(maxdim-mindim))/2.
        igapara._COORDS[2, jcp[1]] = - (mindim + var[i]*(maxdim-mindim))/2.
        
        #igapara._COORDS[0, jcp[2]] =   (mindim + var[i]*(maxdim-mindim))/2.
        igapara._COORDS[2, jcp[2]] =   (mindim + var[i]*(maxdim-mindim))/2.
        
        #igapara._COORDS[0, jcp[3]] = - (mindim + var[i]*(maxdim-mindim))/2.
        igapara._COORDS[2, jcp[3]] =   (mindim + var[i]*(maxdim-mindim))/2.
        
        i += 1
    return None

# %%
# Refinement from optim model to analysis model
nb_deg = np.array([1, 0, 1])
nb_ref = np.array([2, 2, 2])

# %%
# Define optim problem 
optPB = OPTmodelling(modeleIGA, nb_var, shapemodif,
                     nb_degreeElevationByDirection = nb_deg, 
                     nb_refinementByDirection      = nb_ref)
# Out:
#  Refinement has been successfully done.

# %%
# OPTIMISATION
from scipy.optimize import minimize

# Initial values of design variables
x0 = ((1.5-mindim)/(maxdim-mindim))*np.ones(nb_var)
# Compute initial values
v0 = optPB.compute_volume(x0)
c0 = optPB.compute_compliance_discrete(x0)

print('c0 : ', c0)
print('v0 : ', v0)
# Out:
# Compute Volume
# Compute compliance
#  Linear elasticity analysis...
# c0 :  2.200601737296453e-05
# v0 :  13.50000000000045

# %%
vol_var = 0.2

# Define functions and gradients
def volIGA(xk):
    global v0
    return (optPB.compute_volume(xk)-v0)/v0
def gradVolIGA(xk):
    global v0
    return optPB.compute_gradVolume_AN(xk)/v0

def const_var_vol(x_k, *args):
    global v0
    v_k = optPB.compute_volume(x_k)
    return (v_k - (1 - vol_var) * v0) * ((1 + vol_var) * v0 - v_k)/(v0**2.)

def grad_const_var_vol(x_k, *args):
    global v0
    v_k = optPB.compute_volume(x_k)
    grad_v = optPB.compute_gradVolume_AN(x_k)
    return  2 * grad_v * (v0 - v_k)/(v0**2.)
    
def compIGA(xk):
    global c0
    return optPB.compute_compliance_discrete(xk)/c0

def gradCompIGA(xk):
    global c0
    print("INFO gradCompliance :")
    print("x : ", xk)
    print("grad : ", optPB.compute_gradCompliance_AN(xk))
    return optPB.compute_gradCompliance_AN(xk)/c0

# %%
iopt = 0

# %%
# Define callback function
def saveXk(xk):
    global iopt
    print(('\nIteration%i'%iopt))
    print(xk)
    print('C : ', optPB.compute_compliance_discrete(xk))
    print('V : ', optPB.compute_volume(xk))
    SOL,u = rsol.reconstruction(
            **optPB._fineParametrization.get_inputs4solution(optPB._save_sol_fine))
    pp.generatevtu(*optPB._fineParametrization.get_inputs4postprocVTU(
            'OPT3-fine%0.2d'%iopt,  SOL.transpose(), nb_ref=3*np.array([1,1,1]),
            Flag=np.array([True, False, False])))
    
    iopt += 1
    
    return None

# %%
# Bounds for design variables
bds = ((0., 1.),)*nb_var
constraint = ({'type': 'eq', 'fun':volIGA, 'jac':gradVolIGA})
#constraint = [{'type': 'ineq', 'fun': const_var_vol, 'jac': grad_const_var_vol}]
x0 = ((1.5-mindim)/(maxdim-mindim))*np.ones(nb_var)
print('C : ', optPB.compute_compliance_discrete(x0))
print('V : ', optPB.compute_volume(x0))

res = minimize(compIGA, x0, method='SLSQP',
               jac=gradCompIGA, bounds=bds,
               constraints=constraint, callback=saveXk)

print(res)
print('C : ', optPB.compute_compliance_discrete(res['x']))
print('V : ', optPB.compute_volume(res['x']))
# Out:
# Compute compliance
# C :  2.200601737296453e-05
# Compute Volume
# V :  13.50000000000045
# Compute Volume
# Compute compliance
# INFO gradCompliance :
# x :  [0.41176471 0.41176471 0.41176471 0.41176471 0.41176471]
# Compute AN gradient of the compliance
# grad :  [-9.02456265e-06 -8.73764799e-06 -3.67292889e-06 -7.79083047e-07
#  -9.27282413e-08]
# Compute AN gradient of the compliance
# Compute Volume
# Compute AN gradient of the volume
# Compute compliance
#  Linear elasticity analysis...
# Compute Volume
#
# Iteration0
# [0.63022295 0.52136645 0.2912149  0.25553091 0.32015998]
# Compute compliance
# C :  1.7804772074476845e-05
# Compute Volume
# V :  13.500000000000474
#  Post processing ...
#   Map data on FEM mesh ...
#   Writing .vtu file ...
#   --> File OPT3-fine00.vtu has been created.
# INFO gradCompliance :
# x :  [0.63022295 0.52136645 0.2912149  0.25553091 0.32015998]
# Compute AN gradient of the compliance
# grad :  [-2.04489020e-06 -3.51151025e-06 -3.30817991e-06 -8.88952163e-07
#  -6.82887935e-08]
# Compute AN gradient of the compliance
# Compute AN gradient of the volume
# Compute compliance
#  Linear elasticity analysis...
# Compute Volume
#
# Iteration1
# [0.64402142 0.55591548 0.30559384 0.19379347 0.26925404]
# Compute compliance
# C :  1.7133058644001785e-05
# Compute Volume
# V :  13.500000000000227
# INFO gradCompliance :
# x :  [0.64402142 0.55591548 0.30559384 0.19379347 0.26925404]
# Compute AN gradient of the compliance
#  Post processing ...
#   Map data on FEM mesh ...
#   Writing .vtu file ...
#   --> File OPT3-fine01.vtu has been created.
# grad :  [-1.73823997e-06 -2.80033537e-06 -2.70402244e-06 -8.22044619e-07
#  -7.14227070e-08]
# Compute AN gradient of the compliance
# Compute AN gradient of the volume
# Compute compliance
#  Linear elasticity analysis...
# Compute Volume
#
# Iteration2
# [0.69941987 0.65681811 0.35335885 0.00080779 0.09842559]
# Compute compliance
# C :  1.534370776664466e-05
# Compute Volume
# V :  13.5000000000005
# INFO gradCompliance :
# x :  [0.69941987 0.65681811 0.35335885 0.00080779 0.09842559]
# Compute AN gradient of the compliance
#  Post processing ...
#   Map data on FEM mesh ...
#   Writing .vtu file ...
#   --> File OPT3-fine02.vtu has been created.
# grad :  [-9.04890557e-07 -1.34819753e-06 -1.31709308e-06 -4.58624237e-07
#  -6.30450431e-08]
# Compute AN gradient of the compliance
# Compute AN gradient of the volume
# Compute compliance
#  Linear elasticity analysis...
# Compute Volume
#
# Iteration3
# [0.70337787 0.66316482 0.35450019 0.         0.06966099]
# Compute compliance
# C :  1.5237731240603583e-05
# Compute Volume
# V :  13.500000000000528
#  Post processing ...
#   Map data on FEM mesh ...
#   Writing .vtu file ...
#   --> File OPT3-fine03.vtu has been created.
# INFO gradCompliance :
# x :  [0.70337787 0.66316482 0.35450019 0.         0.06966099]
# Compute AN gradient of the compliance
# grad :  [-8.59263139e-07 -1.28602820e-06 -1.24034950e-06 -3.97140481e-07
#  -5.41456302e-08]
# Compute AN gradient of the compliance
# Compute AN gradient of the volume
# Compute compliance
#  Linear elasticity analysis...
# Compute Volume
#
# Iteration4
# [7.12908493e-01 6.79180748e-01 3.55350845e-01 0.00000000e+00
#  1.38777878e-17]
# Compute compliance
# C :  1.4994806890147132e-05
# Compute Volume
# V :  13.500000000000396
#  Post processing ...
# INFO gradCompliance :
# x :  [7.12908493e-01 6.79180748e-01 3.55350845e-01 0.00000000e+00
#  1.38777878e-17]
# Compute AN gradient of the compliance
#   Map data on FEM mesh ...
#   Writing .vtu file ...
#   --> File OPT3-fine04.vtu has been created.
# grad :  [-7.53645090e-07 -1.14389452e-06 -1.07412422e-06 -2.60778558e-07
#  -2.70899000e-08]
# Compute AN gradient of the compliance
# Compute AN gradient of the volume
# Compute compliance
#  Linear elasticity analysis...
# Compute Volume
#
# Iteration5
# [7.13325114e-01 6.80598544e-01 3.53655302e-01 7.24653627e-17
#  0.00000000e+00]
# Compute compliance
# C :  1.4986639928608319e-05
# Compute Volume
# V :  13.500000000000306
#  Post processing ...
# INFO gradCompliance :
# x :  [7.13325114e-01 6.80598544e-01 3.53655302e-01 7.24653627e-17
#  0.00000000e+00]
# Compute AN gradient of the compliance
#   Map data on FEM mesh ...
#   Writing .vtu file ...
#   --> File OPT3-fine05.vtu has been created.
# grad :  [-7.47735809e-07 -1.13573340e-06 -1.07274496e-06 -2.60573501e-07
#  -2.70989909e-08]
# Compute AN gradient of the compliance
# Compute AN gradient of the volume
# Compute compliance
#  Linear elasticity analysis...
# Compute Volume
#
# Iteration6
# [0.71498369 0.68709654 0.34605158 0.         0.        ]
# Compute compliance
# C :  1.4950739206196485e-05
# Compute Volume
# V :  13.500000000000668
#  Post processing ...
# INFO gradCompliance :
# x :  [0.71498369 0.68709654 0.34605158 0.         0.        ]
# Compute AN gradient of the compliance
#   Map data on FEM mesh ...
#   Writing .vtu file ...
#   --> File OPT3-fine06.vtu has been created.
# grad :  [-7.22974811e-07 -1.09979807e-06 -1.06624407e-06 -2.59668160e-07
#  -2.71445791e-08]
# Compute AN gradient of the compliance
# Compute AN gradient of the volume
# Compute compliance
#  Linear elasticity analysis...
# Compute Volume
#
# Iteration7
# [7.16402311e-01 6.94203856e-01 3.37998525e-01 1.89193279e-17
#  1.84314369e-16]
# Compute compliance
# C :  1.4913899646900187e-05
# Compute Volume
# V :  13.500000000000632
#  Post processing ...
# INFO gradCompliance :
# x :  [7.16402311e-01 6.94203856e-01 3.37998525e-01 1.89193279e-17
#  1.84314369e-16]
# Compute AN gradient of the compliance
#   Map data on FEM mesh ...
#   Writing .vtu file ...
#   --> File OPT3-fine07.vtu has been created.
# grad :  [-6.99533793e-07 -1.06294502e-06 -1.05882344e-06 -2.58733943e-07
#  -2.72016338e-08]
# Compute AN gradient of the compliance
# Compute AN gradient of the volume
#
# Iteration8
# [7.16402311e-01 6.94203856e-01 3.37998525e-01 1.89193279e-17
#  1.84314369e-16]
# Compute compliance
# C :  1.4913899646900187e-05
# Compute Volume
# V :  13.500000000000632
#  Post processing ...
#   Map data on FEM mesh ...
#   Writing .vtu file ...
#      fun: 0.6777191617244946
#      jac: array([-0.0317883 , -0.04830247, -0.04811518, -0.01175742, -0.0012361 ])
#  message: 'Optimization terminated successfully'
#     nfev: 9
#      nit: 9
#     njev: 9
#   status: 0
#  success: True
#        x: array([7.16402311e-01, 6.94203856e-01, 3.37998525e-01, 1.89193279e-17,
#        1.84314369e-16])
# Compute compliance
#   --> File OPT3-fine08.vtu has been created.
# C :  1.4913899646900187e-05
# Compute Volume
# V :  13.500000000000632

# %%
optPB.compute_gradCompliance_AN(np.array([0.41176471,0.41176471,0.41176471,0.41176471,0.41176471]))/c0
# Out:
# Compute AN gradient of the compliance
# array([-0.41009522, -0.39705721, -0.16690566, -0.03540318, -0.00421377])
